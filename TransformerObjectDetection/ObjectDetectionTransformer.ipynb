# %%
# !pip install transformers
# !pip install timm
# Out:
# Collecting timm
#   Using cached timm-0.9.2-py3-none-any.whl (2.2 MB)
# Requirement already satisfied: torch>=1.7 in c:\users\hacker\anaconda3\lib\site-packages (from timm) (1.13.1)
# Requirement already satisfied: torchvision in c:\users\hacker\anaconda3\lib\site-packages (from timm) (0.15.0)
# Requirement already satisfied: pyyaml in c:\users\hacker\anaconda3\lib\site-packages (from timm) (6.0)
# Requirement already satisfied: huggingface-hub in c:\users\hacker\anaconda3\lib\site-packages (from timm) (0.15.1)
# Collecting safetensors (from timm)
#   Using cached safetensors-0.3.1-cp39-cp39-win_amd64.whl (263 kB)
# Requirement already satisfied: typing-extensions in c:\users\hacker\anaconda3\lib\site-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: filelock in c:\users\hacker\anaconda3\lib\site-packages (from huggingface-hub->timm) (3.6.0)
# Requirement already satisfied: fsspec in c:\users\hacker\anaconda3\lib\site-packages (from huggingface-hub->timm) (2022.2.0)
# Requirement already satisfied: requests in c:\users\hacker\anaconda3\lib\site-packages (from huggingface-hub->timm) (2.30.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\hacker\anaconda3\lib\site-packages (from huggingface-hub->timm) (4.64.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\hacker\anaconda3\lib\site-packages (from huggingface-hub->timm) (21.3)
# Requirement already satisfied: numpy in c:\users\hacker\anaconda3\lib\site-packages (from torchvision->timm) (1.21.5)
# Collecting torch>=1.7 (from timm)
#   Downloading torch-2.0.0-cp39-cp39-win_amd64.whl (172.3 MB)
#      -                                        8.4/172.3 MB 4.7 kB/s eta 9:35:29
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\Hacker\anaconda3\lib\http\client.py", line 463, in read
#     n = self.readinto(b)
#   File "C:\Users\Hacker\anaconda3\lib\http\client.py", line 507, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\Hacker\anaconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Hacker\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Hacker\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 230, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 173, in _add_to_criteria
#     if not criterion.candidates:
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 156, in __bool__
#     return bool(self._sequence)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 293, in __init__
#     super().__init__(
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 225, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 304, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 516, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 587, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 166, in unpack_url
#     file = get_http_url(
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 107, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 147, in __call__
#     for chunk in chunks:
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\cli\progress_bars.py", line 53, in _rich_progress_bar
#     for chunk in iterable:
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 587, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\Hacker\anaconda3\lib\contextlib.py", line 137, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\Hacker\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.

# %%
from transformers import pipeline
from PIL import Image, ImageDraw, ImageFont

# %%
from transformers import DetrFeatureExtractor, DetrForObjectDetection
feature_extractor = DetrFeatureExtractor.from_pretrained('facebook/detr-resnet-101')
model = DetrForObjectDetection.from_pretrained('facebook/detr-resnet-101')
object_detector = pipeline("object-detection", model = model, feature_extractor = feature_extractor)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/243M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 from transformers import DetrFeatureExtractor, DetrForObjectDetection
#       2 feature_extractor = DetrFeatureExtractor.from_pretrained('facebook/detr-resnet-101')
# ----> 3 model = DetrForObjectDetection.from_pretrained('facebook/detr-resnet-101')
#       4 object_detector = pipeline("object-detection", model = model, feature_extractor = feature_extractor)
#
# File ~\anaconda3\lib\site-packages\transformers\modeling_utils.py:2611, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    2608     init_contexts.append(init_empty_weights())
#    2610 with ContextManagers(init_contexts):
# -> 2611     model = cls(config, *model_args, **model_kwargs)
#    2613 # Check first if we are `from_pt`
#    2614 if use_keep_in_fp32_modules:
#
# File ~\anaconda3\lib\site-packages\transformers\models\detr\modeling_detr.py:1373, in DetrForObjectDetection.__init__(self, config)
#    1370 super().__init__(config)
#    1372 # DETR encoder-decoder model
# -> 1373 self.model = DetrModel(config)
#    1375 # Object detection heads
#    1376 self.class_labels_classifier = nn.Linear(
#    1377     config.d_model, config.num_labels + 1
#    1378 )  # We add one for the "no object" class
#
# File ~\anaconda3\lib\site-packages\transformers\models\detr\modeling_detr.py:1205, in DetrModel.__init__(self, config)
#    1202 super().__init__(config)
#    1204 # Create backbone + positional encoding
# -> 1205 backbone = DetrConvEncoder(config)
#    1206 position_embeddings = build_position_encoding(config)
#    1207 self.backbone = DetrConvModel(backbone, position_embeddings)
#
# File ~\anaconda3\lib\site-packages\transformers\models\detr\modeling_detr.py:337, in DetrConvEncoder.__init__(self, config)
#     334 self.config = config
#     336 if config.use_timm_backbone:
# --> 337     requires_backends(self, ["timm"])
#     338     kwargs = {}
#     339     if config.dilation:
#
# File ~\anaconda3\lib\site-packages\transformers\utils\import_utils.py:1100, in requires_backends(obj, backends)
#    1098 failed = [msg.format(name) for available, msg in checks if not available()]
#    1099 if failed:
# -> 1100     raise ImportError("".join(failed))
#
# ImportError:
# DetrConvEncoder requires the timm library but it was not found in your environment. You can install it with pip:
# `pip install timm`. Please note that you may need to restart your runtime after installation.

# %%
def draw_bounding_box(im, score, label, xmin, ymin, xmax, ymax, index, num_boxes):
    print(f"Drawing bounding box {index} of {num_boxes}...")

    im_with_rectangle = ImageDraw.Draw(im)  
    im_with_rectangle.rectangle((xmin, ymin, xmax, ymax), outline = "red", width = 2)

    im_with_rectangle.text((xmin+35, ymin-25), label, fill="white", stroke_fill = "red")

    return im

# %%
with Image.open("street.jpeg") as im:

	bounding_boxes = object_detector(im)
	num_boxes = len(bounding_boxes)
	index = 0

	for bounding_box in bounding_boxes:
		box = bounding_box["box"]

		im = draw_bounding_box(im, bounding_box["score"], bounding_box["label"],\
			box["xmin"], box["ymin"], box["xmax"], box["ymax"], index, num_boxes)

		index += 1
	im.save("street_bboxes.jpg")
	print("Done!")
# Out:
# Drawing bounding box 0 of 17...
# Drawing bounding box 1 of 17...
# Drawing bounding box 2 of 17...
# Drawing bounding box 3 of 17...
# Drawing bounding box 4 of 17...
# Drawing bounding box 5 of 17...
# Drawing bounding box 6 of 17...
# Drawing bounding box 7 of 17...
# Drawing bounding box 8 of 17...
# Drawing bounding box 9 of 17...
# Drawing bounding box 10 of 17...
# Drawing bounding box 11 of 17...
# Drawing bounding box 12 of 17...
# Drawing bounding box 13 of 17...
# Drawing bounding box 14 of 17...
# Drawing bounding box 15 of 17...
# Drawing bounding box 16 of 17...
# Done!
