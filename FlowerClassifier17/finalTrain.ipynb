# %%
import h5py
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
X = np.array(h5py.File(os.path.join('data', 'X.h5'), 'r')['features'])
y = np.array(h5py.File(os.path.join('data', 'y.h5'), 'r')['targets'])

# %%
np.shape(y)
# Out:
# (1360,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=100)

# %%
rfc = RandomForestClassifier(n_estimators=400)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=400)

# %%
y_pred = rfc.predict(X_test)

# %%
print(classification_report(y_pred=y_pred, y_true=y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.44      0.48        18
#            1       0.47      0.37      0.41        19
#            2       0.70      0.81      0.75        26
#            3       0.76      0.73      0.74        22
#            4       0.57      0.74      0.64        23
#            5       0.57      0.53      0.55        15
#            6       0.79      0.88      0.83        25
#            7       0.78      0.54      0.64        26
#            8       0.88      0.30      0.45        23
#            9       0.75      1.00      0.86        12
#           10       0.63      0.50      0.56        24
#           11       0.55      0.27      0.36        22
#           12       0.58      0.83      0.68        18
#           13       0.83      0.94      0.88        16
#           14       0.30      0.55      0.39        11
#           15       0.50      0.68      0.58        22
#           16       0.67      0.78      0.72        18
#
#     accuracy                           0.63       340
#    macro avg       0.64      0.64      0.62       340
# weighted avg       0.65      0.63      0.62       340

# %%
# MasoudKaviani.ir
